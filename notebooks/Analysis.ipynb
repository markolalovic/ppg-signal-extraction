# %%
library(repr)

# %%
options(repr.plot.width=20, repr.plot.height=10)

# %%
peak.plot <- function(x) {
    t <- 1:length(x)
    plot(t, abs(max(x)-x), col = "blue", type = "l", xlab = "")
}

# %%
df <- read.csv("../data/df-ac-measurements.csv", sep=",", header=TRUE, row.names=NULL)

# %%
head(df, 3)
# Out:
#   id date                device            sys dia hr x0          x1
# 1 0  2020-08-06-15:54:13 Pi NoIR Camera V2 115 54  53 1.224762135  1.28498059
# 2 0  2020-08-06-16:26:09 Pi NoIR Camera V2 116 63  60 0.100274773  0.14958014
# 3 0  2020-08-06-17:06:10 Pi NoIR Camera V2 116 61  54 0.003742374 -0.09963624
#   x2         x3         ⋯ x590        x591        x592       x593
# 1  1.3350016  1.4009264 ⋯ -0.16057161 -0.14725745 -0.1210418 -0.1657789
# 2  0.1887922  0.1919821 ⋯  0.91050829  0.88902047  0.9043827  0.9360904
# 3 -0.1138656 -0.0950838 ⋯  0.07506785  0.08807378  0.1459593  0.1748137
#   x594       x595       x596       x597       x598       x599
# 1 -0.1856440 -0.2282174 -0.2392305 -0.2658273 -0.2513750 -0.2470213
# 2  0.9446319  0.8498595  0.6856862  0.5918221  0.5739909  0.6107236
# 3  0.1905085  0.2052027  0.1979190  0.1681319  0.1774465  0.1898860

# %%
tail(df, 3)
# Out:
#    id date                device    sys dia hr x0       x1       x2
# 20 0  2020-08-07-12:51:01 iPhone 6s 118 72  52 246.4083 246.1696 245.7896
# 21 0  2020-08-07-13:03:46 iPhone 6s 118 72  52 253.1065 253.0736 253.1128
# 22 0  2020-08-07-14:04:57 iPhone 6s 118 72  52 253.7658 253.8012 253.9381
#    x3       ⋯ x590     x591     x592     x593     x594     x595     x596
# 20 245.8455 ⋯ 231.3122 230.8610 230.4154 230.2452 238.4486 242.8363 245.2251
# 21 253.1379 ⋯ 249.6149 249.6284 249.2368 248.8113 248.0936 249.7295 251.4036
# 22 253.9827 ⋯ 253.7884 253.7964 253.7925 253.8156 253.7979 253.8120 253.8190
#    x597     x598     x599
# 20 246.5469 247.4495 248.1325
# 21 252.5019 253.0324 253.4053
# 22 253.8136 253.8060 253.7773

# %%
df.mat <- data.matrix(df)

# %%
peak.plot(as.vector(df.mat[8, 7:606]))
# Out:
# plot without title

# %%
peak.plot(as.vector(df.mat[22, 7:606]))
# Out:
# plot without title
