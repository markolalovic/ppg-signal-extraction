# %%
library(repr)

# %%
options(repr.plot.width=20, repr.plot.height=10)

# %%
peak.plot <- function(x) {
    t <- 1:length(x)
    plot(t, abs(max(x)-x), col = "blue", type = "l", xlab = "")
}

# %%
df <- read.csv("../data/df-ac-measurements.csv", sep=",", header=TRUE, row.names=NULL)

# %%
tail(df, 10)
# Out:
#    id       date                device             sys dia hr x0       x1
# 31   2.0000 2020-08-08-11:24:52 Pi NoIR Camera V2  104 77  81 211.1340 210.7462
# 32   2.0000 2020-08-08-11:33:46 iPhone 6s          104 77  81 253.6135 253.5813
# 33   0.0000 2020-08-08-16:36:42 Pi NoIR Camera V2  115 59  68 216.8063 216.1664
# 34   0.0000 2020-08-08-16:43:22 iPhone 6s          115 59  68 254.0088 254.1708
# 35   0.0000 2020-08-08-16:45:15 Pi NoIR Camera V2  111 63  63 216.2515 216.2784
# 36   0.0000 2020-08-08-16:47:53 iPhone 6s          111 63  63 253.8666 253.9789
# 37   0.0000 2020-08-08-16:51:48 Pi NoIR Camera V2  115 69  66 218.2320 218.2985
# 38   0.0000 2020-08-08-16:55:19 iPhone 6s          106 58  66 254.0246 254.1207
# 39 253.6277 253.42120129243827  253.32373746141974  NA NA  NA       NA       NA
# 40   0.0000 2020-08-08-16:56:46 Pi NoIR Camera V2  106 58  66 216.0408 216.0703
#    x2       x3       ⋯ x590     x591     x592     x593     x594     x595
# 31 210.3468 210.1076 ⋯ 209.7764 209.9343 209.9130 209.4843 208.7964 208.2952
# 32 253.6347 253.6705 ⋯ 253.7402 253.7683 253.7715 253.7861 253.7894 253.7945
# 33 215.9305 216.0882 ⋯ 216.9002 217.0106 217.1012 217.1950 216.6985 215.6498
# 34 254.0934 254.1059 ⋯ 254.1624 254.1691 254.1763 254.1666 254.1163 254.1213
# 35 216.2008 216.1232 ⋯ 215.9915 216.0318 216.0764 216.1430 216.2501 216.3269
# 36 253.7188 253.7273 ⋯ 254.0944 254.1892 254.1712 254.1323 254.1484       NA
# 37 218.3082 218.3253 ⋯ 216.3215 216.3909 216.3938 216.3942 216.3853 216.3510
# 38 254.0679 254.0387 ⋯ 253.9692 253.8624 253.8469 253.8421 253.7764 253.6101
# 39       NA       NA ⋯       NA       NA       NA       NA       NA       NA
# 40 216.1357 216.1743 ⋯ 216.5446 216.6167 216.8400 216.7955 215.9624 215.1812
#    x596     x597     x598     x599
# 31 208.1191 208.0986 208.0684 208.1283
# 32 253.7609 253.6101 253.6554 253.6649
# 33 214.9052 214.7397 214.8739 215.0814
# 34 254.1401 254.1800 254.2090       NA
# 35 216.0346 215.2872 214.7164 214.6310
# 36       NA       NA       NA       NA
# 37 216.3737 216.5013 216.6022 216.6785
# 38 253.7333 253.7500 253.7851 253.7905
# 39       NA       NA       NA       NA
# 40 214.7926 214.7337 214.8746 215.0462

# %%
df.mat <- data.matrix(df)

# %%
peak.plot(as.vector(df.mat[8, 7:606]))
# Out:
# plot without title

# %%
peak.plot(as.vector(df.mat[25, 7:606]))
# Out:
# plot without title

# %%
peak.plot(as.vector(df.mat[24, 7:606]))
# Out:
# plot without title
