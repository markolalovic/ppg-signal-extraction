# %%
peak.plot <- function(x) {
  t <- 1:length(x)
  plot(t, abs(max(x)-x), col = "blue", type = "l",
       xlab = "")
}

# %%
df <- read.csv("../data/df-ac-measurements.csv", 
               sep=",", header=TRUE, row.names=NULL)

# %%
df
# Out:
#   row.names id                  sys dia hr x0        x1        x2
# 1 0         2020-08-06-15:54:13 115 54  53 1.2247621 1.2849806 1.3350016
# 2 0         2020-08-06-16:26:09 116 63  60 0.1002748 0.1495801 0.1887922
#   x3        x4        ⋯ x590       x591       x592       x593       x594
# 1 1.4009264 1.4249556 ⋯ -0.1605716 -0.1472574 -0.1210418 -0.1657789 -0.1856440
# 2 0.1919821 0.2089296 ⋯  0.9105083  0.8890205  0.9043827  0.9360904  0.9446319
#   x595       x596       x597       x598       x599
# 1 -0.2282174 -0.2392305 -0.2658273 -0.2513750 -0.2470213
# 2  0.8498595  0.6856862  0.5918221  0.5739909  0.6107236

# %%
df.mat <- data.matrix(df)

# %%
peak.plot(as.vector(df.mat[1, 6:605]))
# Out:
# plot without title

# %%
peak.plot(as.vector(df.mat[2, 6:605]))
# Out:
# plot without title
